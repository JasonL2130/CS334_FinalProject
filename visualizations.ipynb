# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Data

raw_data = pd.read_csv('/Users/JasonLebov_1/Desktop/CS 334/Final Project/Final Project Data/Original/fraud test.csv')

# %%
# Graph Original Class Distribution

target_dist = raw_data['is_fraud'].value_counts()
target_dist.plot(kind='bar', color='blue')
plt.title('Distribution of Target Values [Original Dataset]')
plt.xlabel('Class')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Graph Class Imbalance --> Training Datasets

    # Import Data
final_full = pd.read_csv('/Users/JasonLebov_1/Desktop/CS 334/Final Project/Final Project Data/Processed Data/final_full_raw.csv')

final_pi_train_xFeat = pd.read_csv('/Users/JasonLebov_1/Desktop/CS 334/Final Project/Final Project Data/Processed Data/pi_train_xFeat.csv')
final_pi_train_y= pd.read_csv('/Users/JasonLebov_1/Desktop/CS 334/Final Project/Final Project Data/Processed Data/pi_train_y.csv')

final_no_pi_train_xFeat = pd.read_csv('/Users/JasonLebov_1/Desktop/CS 334/Final Project/Final Project Data/Processed Data/no_pi_train_xFeat.csv')
final_no_pi_train_y = pd.read_csv('/Users/JasonLebov_1/Desktop/CS 334/Final Project/Final Project Data/Processed Data/no_pi_train_y.csv')

final_pi_test_xFeat = pd.read_csv('/Users/JasonLebov_1/Desktop/CS 334/Final Project/Final Project Data/Processed Data/pi_test_xFeat.csv')
final_pi_test_y = pd.read_csv('/Users/JasonLebov_1/Desktop/CS 334/Final Project/Final Project Data/Processed Data/pi_test_y.csv')

final_no_pi_test_xFeat = pd.read_csv('/Users/JasonLebov_1/Desktop/CS 334/Final Project/Final Project Data/Processed Data/no_pi_test_xFeat.csv')
final_no_pi_test_y = pd.read_csv('/Users/JasonLebov_1/Desktop/CS 334/Final Project/Final Project Data/Processed Data/no_pi_test_y.csv')

# %%
pi_xTrain_y = final_pi_train_y['is_fraud'].value_counts()
pi_xTrain_y.plot(kind='bar', color='blue')
plt.title('Distribution of Target Values [y_train w/ PI]')
plt.xlabel('Class')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
no_i_xTrain_y = final_no_pi_train_y['is_fraud'].value_counts()
no_i_xTrain_y.plot(kind='bar', color='blue')
plt.title('Distribution of Target Values [y_train w/ Out PI]')
plt.xlabel('Class')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Graph Pearson Correlation Matrix
    # --> DONE
